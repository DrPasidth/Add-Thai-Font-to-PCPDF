# %% [markdown]
# <a href="https://colab.research.google.com/github/DrPasidth/Add-Thai-Font-to-PCPDF/blob/main/VibrationFFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fftpack import fft, ifft
import matplotlib.mlab as mlab

# %%
filename = 'Vx.csv'
df = pd.read_csv('Vx.csv', index_col=['DateTime'], parse_dates=['DateTime'])
print(df.head())
data = pd.read_csv(filename)
ConvertToMatrix = data.values
print(data)
# Out:
#                        Vx
# DateTime
# 2023-11-12 08:48:00  0.31
# 2023-11-12 08:49:00  0.36
# 2023-11-12 08:50:00  0.34
# 2023-11-12 08:51:00  0.30
# 2023-11-12 08:52:00  0.33
#             DateTime    Vx
# 0    11/12/2023 8:48  0.31
# 1    11/12/2023 8:49  0.36
# 2    11/12/2023 8:50  0.34
# 3    11/12/2023 8:51  0.30
# 4    11/12/2023 8:52  0.33
# ..               ...   ...
# 514  12/25/2023 9:22  0.00
# 515  12/25/2023 9:23  0.00
# 516  12/25/2023 9:24  0.00
# 517  12/25/2023 9:25  0.00
# 518  12/25/2023 9:28  0.00
#
# [519 rows x 2 columns]

# %%
plt.figure(figsize=(12,4))
df.plot(linestyle = '', marker = '*', color='r')
plt.show()

# %%
N = 519
#frequency of signal
T = 1
#create x-axis for time length of signal
x = np.linspace(0, N*T, N)
#create array that corresponds to values in signal
y = df
#perform FFT on signal
yf = fft(y)
#create new x-axis: frequency from signal
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
#plot results
plt.plot(xf, yf[0:N//2], label = 'signal')
plt.grid()
plt.xlabel('Frequency (days)')
plt.ylabel(r'Spectral Amplitude')
plt.legend(loc=1)
plt.savefig('freqSpectrum.jpg')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
